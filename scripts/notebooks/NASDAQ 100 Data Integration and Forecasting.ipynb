# %% [markdown]
# # NASDAQ 100 Data Integration and Forecasting

# %% [markdown]
# **Installing Necessary Libraries**

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\shamg\anaconda3\lib\site-packages (0.2.64)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\shamg\anaconda3\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\shamg\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\shamg\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\shamg\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\shamg\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\shamg\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\shamg\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\shamg\anaconda3\lib\site-packages (from yfinance) (3.18.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\shamg\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\shamg\anaconda3\lib\site-packages (from yfinance) (0.11.4)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\shamg\anaconda3\lib\site-packages (from yfinance) (4.25.3)
# Requirement already satisfied: websockets>=13.0 in c:\users\shamg\anaconda3\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\shamg\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\shamg\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\shamg\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shamg\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shamg\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shamg\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shamg\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shamg\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: pycparser in c:\users\shamg\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\shamg\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)

# %% [markdown]
# **Downloading and Merging NASDAQ-100 Stock Data**

# %%
import yfinance as yf
import pandas as pd
from functools import reduce
from datetime import datetime

tickers = [
    'AAPL', 'MSFT', 'AMZN', 'NVDA', 'META', 'GOOG', 'GOOGL', 'AVGO', 'COST', 'PEP',
    'ADBE', 'TSLA', 'AMD', 'CMCSA', 'NFLX', 'INTC', 'CSCO', 'AMGN', 'TMUS', 'QCOM',
    'TXN', 'HON', 'INTU', 'SBUX', 'ISRG', 'AMAT', 'BKNG', 'ADI', 'MDLZ', 'REGN',
    'VRTX', 'GILD', 'MU', 'ADP', 'PANW', 'LRCX', 'MAR', 'KLAC', 'CTSH', 'CDNS',
    'CSGP', 'ORLY', 'DXCM', 'ROST', 'MNST', 'KDP', 'FTNT', 'IDXX', 'AZN', 'BIIB',
    'WDAY', 'CHTR', 'PAYX', 'ODFL', 'ANSS', 'AEP', 'EA', 'XEL', 'DLTR', 'MELI',
    'PCAR', 'ALGN', 'FAST', 'CPRT', 'CTAS', 'CDW', 'WBD', 'VRSK', 'BKR', 'SIRI',
    'EBAY', 'WBA', 'MTCH', 'BIDU', 'JD', 'TTWO', 'VRSN', 'ULTA', 'NXPI', 'CHKP', 'INCY'
]

start_date = "2015-01-01"
end_date = datetime.today().strftime('%Y-%m-%d')

# Base date range
base_dates = pd.date_range(start=start_date, end=end_date, freq='B')
base_df = pd.DataFrame({'Date': base_dates})

stock_dfs = []
failed_tickers = []

for ticker in tickers:
    try:
        stock = yf.Ticker(ticker)
        hist = stock.history(start=start_date, end=end_date, auto_adjust=False)

        if hist.empty or 'Close' not in hist.columns or 'Volume' not in hist.columns:
            raise ValueError("Missing 'Close' or 'Volume'")

        # Normalize timezone to prevent merge conflict
        df = pd.DataFrame({
            'Date': hist.index.tz_localize(None),  # Strip timezone
            f"{ticker}_CLOSE": hist['Close'].values,
            f"{ticker}_VOLUME": hist['Volume'].values
        })

        df = pd.merge(base_df, df, on='Date', how='left')
        stock_dfs.append(df)

    except Exception as e:
        print(f"Error downloading {ticker}: {e}")
        failed_tickers.append(ticker)

# Final merge
if not stock_dfs:
    raise RuntimeError("All downloads failed. No data to merge.")

final_df = reduce(lambda left, right: pd.merge(left, right, on='Date', how='outer'), stock_dfs)
final_df.sort_values("Date", inplace=True)
final_df.to_csv(r"D:\Masters Study Abroad\BA 2nd Sem\IS6611 Applied Research in Business Analytics\IS6611 IT Artefact V3\Final Files\Final Datasets\NASDAQ Datasets\NASDAQ_100_final_timezone_fixed.csv", index=False)

print("\nMerge complete.")
print(f"Tickers downloaded: {len(stock_dfs)}")
print(f"Failed tickers: {failed_tickers if failed_tickers else 'None'}")
final_df.head()
# Out:
# Merge complete.
# Tickers downloaded: 81
# Failed tickers: None
#         Date  AAPL_CLOSE  AAPL_VOLUME  MSFT_CLOSE  MSFT_VOLUME  AMZN_CLOSE  \
# 0 2015-01-01         NaN          NaN         NaN          NaN         NaN
# 1 2015-01-02   27.332500  212818400.0   46.759998   27913900.0     15.4260
# 2 2015-01-05   26.562500  257142000.0   46.330002   39673900.0     15.1095
# 3 2015-01-06   26.565001  263188400.0   45.650002   36447900.0     14.7645
# 4 2015-01-07   26.937500  160423600.0   46.230000   29114100.0     14.9210
#
#    AMZN_VOLUME  NVDA_CLOSE  NVDA_VOLUME  META_CLOSE  ...  VRSN_CLOSE  \
# 0          NaN         NaN          NaN         NaN  ...         NaN
# 1   55664000.0     0.50325  113680000.0   78.449997  ...   57.189999
# 2   55484000.0     0.49475  197952000.0   77.190002  ...   56.240002
# 3   70380000.0     0.47975  197764000.0   76.150002  ...   55.180000
# 4   52806000.0     0.47850  321808000.0   76.150002  ...   55.639999
#
#    VRSN_VOLUME  ULTA_CLOSE  ULTA_VOLUME  NXPI_CLOSE  NXPI_VOLUME  CHKP_CLOSE  \
# 0          NaN         NaN          NaN         NaN          NaN         NaN
# 1     684500.0  126.839996     410800.0   76.809998    2566600.0   78.459999
# 2     874400.0  127.150002     477400.0   76.000000    3929600.0   78.010002
# 3    1289300.0  126.949997     758200.0   72.379997    4099700.0   77.949997
# 4     552400.0  130.580002     597200.0   74.330002    2713000.0   78.589996
#
#    CHKP_VOLUME  INCY_CLOSE  INCY_VOLUME
# 0          NaN         NaN          NaN
# 1     569000.0   73.760002     775100.0
# 2     720800.0   74.220001     968900.0
# 3    1641600.0   71.489998    2249200.0
# 4     751700.0   74.449997    1009100.0
#
# [5 rows x 163 columns]

# %% [markdown]
# **Calculating Top 5 and Bottom 5 Performing NASDAQ Stocks**

# %%
import numpy as np
import pandas as pd

# Assuming your merged file is loaded as:
df = pd.read_csv(r"D:\Masters Study Abroad\BA 2nd Sem\IS6611 Applied Research in Business Analytics\IS6611 IT Artefact V3\Final Files\Final Datasets\NASDAQ Datasets\NASDAQ_100_final_timezone_fixed.csv", parse_dates=['Date'])
df.set_index('Date', inplace=True)

# Get all _CLOSE columns
close_cols = [col for col in df.columns if col.endswith('_CLOSE')]

cagr_results = []

for col in close_cols:
    stock_series = df[col].dropna()
    
    # Skip if not enough data
    if stock_series.shape[0] < 2:
        continue

    start_price = stock_series.iloc[0]
    end_price = stock_series.iloc[-1]
    start_date = stock_series.index[0]
    end_date = stock_series.index[-1]

    # Calculate the number of years between start and end
    years = (end_date - start_date).days / 365.25

    if start_price > 0 and years > 0:
        cagr = (end_price / start_price) ** (1 / years) - 1
        cagr_results.append({
            'Stock': col.replace('_CLOSE', ''),
            'CAGR': cagr,
            'Start Date': start_date.date(),
            'End Date': end_date.date()
        })

# Create DataFrame
cagr_df = pd.DataFrame(cagr_results)
cagr_df['CAGR (%)'] = cagr_df['CAGR'] * 100

# Sort by CAGR
cagr_df_sorted = cagr_df.sort_values(by='CAGR', ascending=False)

# Top and Bottom 5
top_5 = cagr_df_sorted.head(5).reset_index(drop=True)
bottom_5 = cagr_df_sorted.tail(5).reset_index(drop=True)

# Display Results
print("Top 5 Performing Stocks by CAGR (%):\n")
print(top_5[['Stock', 'CAGR (%)', 'Start Date', 'End Date']])

print("\nBottom 5 Performing Stocks by CAGR (%):\n")
print(bottom_5[['Stock', 'CAGR (%)', 'Start Date', 'End Date']])
# Out:
# Top 5 Performing Stocks by CAGR (%):
#
#   Stock   CAGR (%)  Start Date    End Date
# 0  NVDA  72.987683  2015-01-02  2025-07-08
# 1   AMD  45.518032  2015-01-02  2025-07-08
# 2  AVGO  36.894062  2015-01-02  2025-07-08
# 3  NFLX  36.119858  2015-01-02  2025-07-08
# 4  TSLA  33.200465  2015-01-02  2025-07-08
#
# Bottom 5 Performing Stocks by CAGR (%):
#
#   Stock   CAGR (%)  Start Date    End Date
# 0   KDP  -6.830816  2015-01-02  2025-07-08
# 1  BIDU  -8.244650  2015-01-02  2025-07-08
# 2  BIIB  -8.497039  2015-01-02  2025-07-08
# 3   WBD  -9.984569  2015-01-02  2025-07-08
# 4   WBA -16.427253  2015-01-02  2025-07-08

# %% [markdown]
# **VAR Forecasting for Top 5 Stocks**

# %% [markdown]
# **NVDA**

# %%
from statsmodels.tsa.api import VAR
from statsmodels.stats.diagnostic import acorr_ljungbox

import matplotlib.pyplot as plt
import pandas as pd

# 1. Define the stock
stock = 'NVDA'

# 2. Prepare the data
ts_stock = df[[f'{stock}_CLOSE', f'{stock}_VOLUME']].dropna()

# 3. Use only last 3 years (or change to 5 if needed)
end_date = ts_stock.index.max()
start_cutoff = end_date - pd.DateOffset(years=3)
ts_stock = ts_stock.loc[ts_stock.index >= start_cutoff]

# 4. Set business day frequency and forward fill missing
ts_stock = ts_stock.asfreq('B').fillna(method='ffill')

# 5. Difference the series to make it stationary
ts_stock_diff = ts_stock.diff().dropna()

# 6. Fit the VAR model
model = VAR(ts_stock_diff)
lag_order = model.select_order(15).aic
fitted_model = model.fit(lag_order)

# 7. Forecast next 60 business days
forecast_steps = 60
forecast_input = ts_stock_diff.values[-lag_order:]
forecast = fitted_model.forecast(y=forecast_input, steps=forecast_steps)
forecast_df = pd.DataFrame(forecast, columns=ts_stock_diff.columns)

# 8. Invert differencing
last_known = ts_stock.iloc[-1]
forecast_cumsum = forecast_df.cumsum()
forecast_restored = forecast_cumsum.add(last_known)

# 9. Assign dates to forecast
forecast_dates = pd.date_range(start=ts_stock.index[-1] + pd.Timedelta(days=1), periods=forecast_steps, freq='B')
forecast_restored.index = forecast_dates

# 10. Plot the forecast
plt.figure(figsize=(12, 6))
plt.plot(ts_stock[f'{stock}_CLOSE'][-60:], label='Historical')
plt.plot(forecast_restored[f'{stock}_CLOSE'], label='Forecast', linestyle='--')
plt.title(f"{stock} Forecasted Close Price (Next {forecast_steps} Business Days)")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# 11. Print summary
print(f"\nVAR Model Summary for {stock} (Lag={lag_order}):")
print(fitted_model.summary())

# 12. Ljung-Box Test for autocorrelation
from statsmodels.stats.diagnostic import acorr_ljungbox

print("\nLjung-Box Test for Residuals (one per variable):")
for col in fitted_model.resid.columns:
    lb_test = acorr_ljungbox(fitted_model.resid[col], lags=[lag_order], return_df=True)
    p_value = lb_test['lb_pvalue'].values[0]
    print(f"{col}: p-value = {p_value:.4f} {'No autocorrelation' if p_value > 0.05 else 'Possibly autocorrelated'}")
# Out:
# C:\Users\shamg\AppData\Local\Temp\ipykernel_13408\501901937.py:19: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ts_stock = ts_stock.asfreq('B').fillna(method='ffill')
# VAR Model Summary for NVDA (Lag=4):
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 09, Jul, 2025
# Time:                     09:06:03
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    39.4141
# Nobs:                     778.000    HQIC:                   39.3478
# Log likelihood:          -17480.0    FPE:                1.17633e+17
# AIC:                      39.3063    Det(Omega_mle):     1.14958e+17
# --------------------------------------------------------------------
# Results for equation NVDA_CLOSE
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.203764         0.102194            1.994           0.046
# L1.NVDA_CLOSE         -0.082351         0.036194           -2.275           0.023
# L1.NVDA_VOLUME         0.000000         0.000000            1.168           0.243
# L2.NVDA_CLOSE          0.057271         0.036296            1.578           0.115
# L2.NVDA_VOLUME         0.000000         0.000000            0.525           0.600
# L3.NVDA_CLOSE         -0.041393         0.036303           -1.140           0.254
# L3.NVDA_VOLUME         0.000000         0.000000            0.473           0.636
# L4.NVDA_CLOSE         -0.026325         0.036235           -0.727           0.468
# L4.NVDA_VOLUME         0.000000         0.000000            0.165           0.869
# =================================================================================
#
# Results for equation NVDA_VOLUME
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const            -506336.870910   4361753.858082           -0.116           0.908
# L1.NVDA_CLOSE    -315025.916206   1544797.383346           -0.204           0.838
# L1.NVDA_VOLUME        -0.432488         0.035946          -12.032           0.000
# L2.NVDA_CLOSE   -1179367.624847   1549159.495996           -0.761           0.446
# L2.NVDA_VOLUME        -0.362434         0.038191           -9.490           0.000
# L3.NVDA_CLOSE    1267616.345238   1549472.411569            0.818           0.413
# L3.NVDA_VOLUME        -0.240314         0.038195           -6.292           0.000
# L4.NVDA_CLOSE   -1947827.622363   1546559.602702           -1.259           0.208
# L4.NVDA_VOLUME        -0.112896         0.035924           -3.143           0.002
# =================================================================================
#
# Correlation matrix of residuals
#                NVDA_CLOSE  NVDA_VOLUME
# NVDA_CLOSE       1.000000    -0.088654
# NVDA_VOLUME     -0.088654     1.000000
#
#
#
#
# Ljung-Box Test for Residuals (one per variable):
# NVDA_CLOSE: p-value = 1.0000 No autocorrelation
# NVDA_VOLUME: p-value = 0.7654 No autocorrelation

# %%
forecasted_closes = {}
forecasted_closes['NVDA'] = forecast_restored

# %%
# Choose last N steps for comparison
n = 60
actual = ts_stock[-n:]
predicted = ts_stock.shift(1).dropna()[-n:]  # naive 1-step ahead for demo

# Filter to 'NVDA_CLOSE' only
column = 'NVDA_CLOSE'

y_true = actual[column]
y_pred = predicted[column]

# Ensure lengths match
if len(y_true) != len(y_pred):
    print(f"⚠️ Mismatched lengths: y_true = {len(y_true)}, y_pred = {len(y_pred)}")
else:
    # Fix division by zero in MAPE
    nonzero_mask = y_true != 0
    mape = np.mean(np.abs((y_true[nonzero_mask] - y_pred[nonzero_mask]) / y_true[nonzero_mask])) * 100

    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)

    print(f"\n Accuracy Metrics for {column}:")
    print(f"  MSE  : {mse:.2f}")
    print(f"  RMSE : {rmse:.2f}")
    print(f"  MAE  : {mae:.2f}")
    print(f"  MAPE : {mape:.2f}%")
    print(f"  R²   : {r2:.4f}")
# Out:
#  Accuracy Metrics for NVDA_CLOSE:
#   MSE  : 8.79
#   RMSE : 2.96
#   MAE  : 2.26
#   MAPE : 1.77%
#   R²   : 0.9728

# %% [markdown]
# **AMD**

# %%
# 1. Define the stock
stock = 'AMD'

# 2. Prepare the data
ts_stock = df[[f'{stock}_CLOSE', f'{stock}_VOLUME']].dropna()

# 3. Use only last 3 years (or change to 5 if needed)
end_date = ts_stock.index.max()
start_cutoff = end_date - pd.DateOffset(years=3)
ts_stock = ts_stock.loc[ts_stock.index >= start_cutoff]

# 4. Set business day frequency and forward fill missing
ts_stock = ts_stock.asfreq('B').fillna(method='ffill')

# 5. Difference the series to make it stationary
ts_stock_diff = ts_stock.diff().dropna()

# 6. Fit the VAR model
model = VAR(ts_stock_diff)
lag_order = model.select_order(15).aic
fitted_model = model.fit(lag_order)

# 7. Forecast next 60 business days
forecast_steps = 60
forecast_input = ts_stock_diff.values[-lag_order:]
forecast = fitted_model.forecast(y=forecast_input, steps=forecast_steps)
forecast_df = pd.DataFrame(forecast, columns=ts_stock_diff.columns)

# 8. Invert differencing
last_known = ts_stock.iloc[-1]
forecast_cumsum = forecast_df.cumsum()
forecast_restored = forecast_cumsum.add(last_known)

# 9. Assign dates to forecast
forecast_dates = pd.date_range(start=ts_stock.index[-1] + pd.Timedelta(days=1), periods=forecast_steps, freq='B')
forecast_restored.index = forecast_dates

# 10. Plot the forecast
plt.figure(figsize=(12, 6))
plt.plot(ts_stock[f'{stock}_CLOSE'][-60:], label='Historical')
plt.plot(forecast_restored[f'{stock}_CLOSE'], label='Forecast', linestyle='--')
plt.title(f"{stock} Forecasted Close Price (Next {forecast_steps} Business Days)")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# 11. Print summary
print(f"\nVAR Model Summary for {stock} (Lag={lag_order}):")
print(fitted_model.summary())

# 12. Ljung-Box Test for autocorrelation
from statsmodels.stats.diagnostic import acorr_ljungbox

print("\nLjung-Box Test for Residuals (one per variable):")
for col in fitted_model.resid.columns:
    lb_test = acorr_ljungbox(fitted_model.resid[col], lags=[lag_order], return_df=True)
    p_value = lb_test['lb_pvalue'].values[0]
    print(f"{col}: p-value = {p_value:.4f} {'No autocorrelation' if p_value > 0.05 else 'Possibly autocorrelated'}")
# Out:
# C:\Users\shamg\AppData\Local\Temp\ipykernel_13408\1466095722.py:13: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ts_stock = ts_stock.asfreq('B').fillna(method='ffill')
# VAR Model Summary for AMD (Lag=6):
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 09, Jul, 2025
# Time:                     09:06:03
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    36.0661
# Nobs:                     776.000    HQIC:                   35.9702
# Log likelihood:          -16109.3    FPE:                3.94097e+15
# AIC:                      35.9102    Det(Omega_mle):     3.81218e+15
# --------------------------------------------------------------------
# Results for equation AMD_CLOSE
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.069140         0.133296            0.519           0.604
# L1.AMD_CLOSE         -0.003329         0.036189           -0.092           0.927
# L1.AMD_VOLUME        -0.000000         0.000000           -0.232           0.816
# L2.AMD_CLOSE          0.021490         0.036231            0.593           0.553
# L2.AMD_VOLUME         0.000000         0.000000            1.368           0.171
# L3.AMD_CLOSE         -0.019747         0.036205           -0.545           0.585
# L3.AMD_VOLUME         0.000000         0.000000            0.634           0.526
# L4.AMD_CLOSE         -0.037584         0.036155           -1.040           0.299
# L4.AMD_VOLUME        -0.000000         0.000000           -1.045           0.296
# L5.AMD_CLOSE         -0.021344         0.036150           -0.590           0.555
# L5.AMD_VOLUME        -0.000000         0.000000           -0.696           0.487
# L6.AMD_CLOSE          0.111256         0.036211            3.072           0.002
# L6.AMD_VOLUME         0.000000         0.000000            0.470           0.639
# ================================================================================
#
# Results for equation AMD_VOLUME
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const           -167670.251967    602226.602542           -0.278           0.781
# L1.AMD_CLOSE     244848.992549    163501.721098            1.498           0.134
# L1.AMD_VOLUME        -0.386712         0.036267          -10.663           0.000
# L2.AMD_CLOSE     -30179.619365    163689.157715           -0.184           0.854
# L2.AMD_VOLUME        -0.319079         0.038767           -8.231           0.000
# L3.AMD_CLOSE     254135.478626    163571.285145            1.554           0.120
# L3.AMD_VOLUME        -0.269579         0.040152           -6.714           0.000
# L4.AMD_CLOSE    -292698.865643    163347.814484           -1.792           0.073
# L4.AMD_VOLUME        -0.143793         0.040189           -3.578           0.000
# L5.AMD_CLOSE      37216.671415    163325.993443            0.228           0.820
# L5.AMD_VOLUME        -0.088727         0.038840           -2.284           0.022
# L6.AMD_CLOSE     129314.363763    163599.428609            0.790           0.429
# L6.AMD_VOLUME        -0.083051         0.036287           -2.289           0.022
# ================================================================================
#
# Correlation matrix of residuals
#               AMD_CLOSE  AMD_VOLUME
# AMD_CLOSE      1.000000    0.107175
# AMD_VOLUME     0.107175    1.000000
#
#
#
#
# Ljung-Box Test for Residuals (one per variable):
# AMD_CLOSE: p-value = 1.0000 No autocorrelation
# AMD_VOLUME: p-value = 0.7184 No autocorrelation

# %%
forecasted_closes['AMD'] = forecast_restored

# %% [markdown]
# **AVGO**

# %%
# 1. Define the stock
stock = 'AVGO'

# 2. Prepare the data
ts_stock = df[[f'{stock}_CLOSE', f'{stock}_VOLUME']].dropna()

# 3. Use only last 3 years (or change to 5 if needed)
end_date = ts_stock.index.max()
start_cutoff = end_date - pd.DateOffset(years=3)
ts_stock = ts_stock.loc[ts_stock.index >= start_cutoff]

# 4. Set business day frequency and forward fill missing
ts_stock = ts_stock.asfreq('B').fillna(method='ffill')

# 5. Difference the series to make it stationary
ts_stock_diff = ts_stock.diff().dropna()

# 6. Fit the VAR model
model = VAR(ts_stock_diff)
lag_order = model.select_order(15).aic
fitted_model = model.fit(lag_order)

# 7. Forecast next 60 business days
forecast_steps = 60
forecast_input = ts_stock_diff.values[-lag_order:]
forecast = fitted_model.forecast(y=forecast_input, steps=forecast_steps)
forecast_df = pd.DataFrame(forecast, columns=ts_stock_diff.columns)

# 8. Invert differencing
last_known = ts_stock.iloc[-1]
forecast_cumsum = forecast_df.cumsum()
forecast_restored = forecast_cumsum.add(last_known)

# 9. Assign dates to forecast
forecast_dates = pd.date_range(start=ts_stock.index[-1] + pd.Timedelta(days=1), periods=forecast_steps, freq='B')
forecast_restored.index = forecast_dates

# 10. Plot the forecast
plt.figure(figsize=(12, 6))
plt.plot(ts_stock[f'{stock}_CLOSE'][-60:], label='Historical')
plt.plot(forecast_restored[f'{stock}_CLOSE'], label='Forecast', linestyle='--')
plt.title(f"{stock} Forecasted Close Price (Next {forecast_steps} Business Days)")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# 11. Print summary
print(f"\nVAR Model Summary for {stock} (Lag={lag_order}):")
print(fitted_model.summary())

# 12. Ljung-Box Test for autocorrelation
from statsmodels.stats.diagnostic import acorr_ljungbox

print("\nLjung-Box Test for Residuals (one per variable):")
for col in fitted_model.resid.columns:
    lb_test = acorr_ljungbox(fitted_model.resid[col], lags=[lag_order], return_df=True)
    p_value = lb_test['lb_pvalue'].values[0]
    print(f"{col}: p-value = {p_value:.4f} {'No autocorrelation' if p_value > 0.05 else 'Possibly autocorrelated'}")
# Out:
# C:\Users\shamg\AppData\Local\Temp\ipykernel_13408\3233196051.py:13: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ts_stock = ts_stock.asfreq('B').fillna(method='ffill')
# VAR Model Summary for AVGO (Lag=9):
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 09, Jul, 2025
# Time:                     09:06:04
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    36.0042
# Nobs:                     773.000    HQIC:                   35.8635
# Log likelihood:          -15982.9    FPE:                3.44456e+15
# AIC:                      35.7756    Det(Omega_mle):     3.28127e+15
# --------------------------------------------------------------------
# Results for equation AVGO_CLOSE
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.298199         0.164273            1.815           0.069
# L1.AVGO_CLOSE         -0.001904         0.036380           -0.052           0.958
# L1.AVGO_VOLUME         0.000000         0.000000            2.659           0.008
# L2.AVGO_CLOSE          0.056718         0.036382            1.559           0.119
# L2.AVGO_VOLUME         0.000000         0.000000            2.139           0.032
# L3.AVGO_CLOSE         -0.100673         0.036436           -2.763           0.006
# L3.AVGO_VOLUME         0.000000         0.000000            1.680           0.093
# L4.AVGO_CLOSE         -0.121643         0.036700           -3.315           0.001
# L4.AVGO_VOLUME         0.000000         0.000000            0.888           0.375
# L5.AVGO_CLOSE          0.073158         0.036908            1.982           0.047
# L5.AVGO_VOLUME        -0.000000         0.000000           -1.129           0.259
# L6.AVGO_CLOSE          0.028188         0.036936            0.763           0.445
# L6.AVGO_VOLUME        -0.000000         0.000000           -0.747           0.455
# L7.AVGO_CLOSE         -0.016414         0.036747           -0.447           0.655
# L7.AVGO_VOLUME        -0.000000         0.000000           -0.620           0.535
# L8.AVGO_CLOSE         -0.031149         0.036580           -0.852           0.394
# L8.AVGO_VOLUME        -0.000000         0.000000           -0.505           0.614
# L9.AVGO_CLOSE          0.076324         0.036633            2.083           0.037
# L9.AVGO_VOLUME         0.000000         0.000000            0.552           0.581
# =================================================================================
#
# Results for equation AVGO_VOLUME
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const              77017.859592    471314.945305            0.163           0.870
# L1.AVGO_CLOSE      63470.314395    104378.930597            0.608           0.543
# L1.AVGO_VOLUME        -0.464521         0.036305          -12.795           0.000
# L2.AVGO_CLOSE     -13473.322033    104383.069550           -0.129           0.897
# L2.AVGO_VOLUME        -0.332822         0.039332           -8.462           0.000
# L3.AVGO_CLOSE    -161631.984070    104539.195371           -1.546           0.122
# L3.AVGO_VOLUME        -0.185598         0.040420           -4.592           0.000
# L4.AVGO_CLOSE      28726.697854    105295.517141            0.273           0.785
# L4.AVGO_VOLUME        -0.084684         0.040512           -2.090           0.037
# L5.AVGO_CLOSE     261054.087304    105892.977221            2.465           0.014
# L5.AVGO_VOLUME        -0.062781         0.040651           -1.544           0.122
# L6.AVGO_CLOSE     -61163.442931    105972.869344           -0.577           0.564
# L6.AVGO_VOLUME        -0.172722         0.040632           -4.251           0.000
# L7.AVGO_CLOSE     -51295.322696    105430.426561           -0.487           0.627
# L7.AVGO_VOLUME        -0.226177         0.040498           -5.585           0.000
# L8.AVGO_CLOSE    -210096.926654    104950.923013           -2.002           0.045
# L8.AVGO_VOLUME        -0.220763         0.039386           -5.605           0.000
# L9.AVGO_CLOSE    -148449.306023    105103.906551           -1.412           0.158
# L9.AVGO_VOLUME        -0.084066         0.036292           -2.316           0.021
# =================================================================================
#
# Correlation matrix of residuals
#                AVGO_CLOSE  AVGO_VOLUME
# AVGO_CLOSE       1.000000     0.069521
# AVGO_VOLUME      0.069521     1.000000
#
#
#
#
# Ljung-Box Test for Residuals (one per variable):
# AVGO_CLOSE: p-value = 1.0000 No autocorrelation
# AVGO_VOLUME: p-value = 0.9998 No autocorrelation

# %%
forecasted_closes['AVGO'] = forecast_restored

# %% [markdown]
# **NFLX**

# %%
# 1. Define the stock
stock = 'NFLX'

# 2. Prepare the data
ts_stock = df[[f'{stock}_CLOSE', f'{stock}_VOLUME']].dropna()

# 3. Use only last 3 years (or change to 5 if needed)
end_date = ts_stock.index.max()
start_cutoff = end_date - pd.DateOffset(years=3)
ts_stock = ts_stock.loc[ts_stock.index >= start_cutoff]

# 4. Set business day frequency and forward fill missing
ts_stock = ts_stock.asfreq('B').fillna(method='ffill')

# 5. Difference the series to make it stationary
ts_stock_diff = ts_stock.diff().dropna()

# 6. Fit the VAR model
model = VAR(ts_stock_diff)
lag_order = model.select_order(15).aic
fitted_model = model.fit(lag_order)

# 7. Forecast next 60 business days
forecast_steps = 60
forecast_input = ts_stock_diff.values[-lag_order:]
forecast = fitted_model.forecast(y=forecast_input, steps=forecast_steps)
forecast_df = pd.DataFrame(forecast, columns=ts_stock_diff.columns)

# 8. Invert differencing
last_known = ts_stock.iloc[-1]
forecast_cumsum = forecast_df.cumsum()
forecast_restored = forecast_cumsum.add(last_known)

# 9. Assign dates to forecast
forecast_dates = pd.date_range(start=ts_stock.index[-1] + pd.Timedelta(days=1), periods=forecast_steps, freq='B')
forecast_restored.index = forecast_dates

# 10. Plot the forecast
plt.figure(figsize=(12, 6))
plt.plot(ts_stock[f'{stock}_CLOSE'][-60:], label='Historical')
plt.plot(forecast_restored[f'{stock}_CLOSE'], label='Forecast', linestyle='--')
plt.title(f"{stock} Forecasted Close Price (Next {forecast_steps} Business Days)")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# 11. Print summary
print(f"\nVAR Model Summary for {stock} (Lag={lag_order}):")
print(fitted_model.summary())

# 12. Ljung-Box Test for autocorrelation
from statsmodels.stats.diagnostic import acorr_ljungbox

print("\nLjung-Box Test for Residuals (one per variable):")
for col in fitted_model.resid.columns:
    lb_test = acorr_ljungbox(fitted_model.resid[col], lags=[lag_order], return_df=True)
    p_value = lb_test['lb_pvalue'].values[0]
    print(f"{col}: p-value = {p_value:.4f} {'No autocorrelation' if p_value > 0.05 else 'Possibly autocorrelated'}")
# Out:
# C:\Users\shamg\AppData\Local\Temp\ipykernel_13408\3738200960.py:13: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ts_stock = ts_stock.asfreq('B').fillna(method='ffill')
# VAR Model Summary for NFLX (Lag=5):
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 09, Jul, 2025
# Time:                     09:06:04
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    35.2344
# Nobs:                     777.000    HQIC:                   35.1533
# Log likelihood:          -15820.4    FPE:                1.75736e+15
# AIC:                      35.1026    Det(Omega_mle):     1.70864e+15
# --------------------------------------------------------------------
# Results for equation NFLX_CLOSE
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  1.255280         0.476685            2.633           0.008
# L1.NFLX_CLOSE         -0.004469         0.036398           -0.123           0.902
# L1.NFLX_VOLUME         0.000000         0.000000            1.706           0.088
# L2.NFLX_CLOSE          0.025587         0.036554            0.700           0.484
# L2.NFLX_VOLUME         0.000000         0.000000            2.159           0.031
# L3.NFLX_CLOSE         -0.030310         0.036522           -0.830           0.407
# L3.NFLX_VOLUME         0.000000         0.000000            1.159           0.246
# L4.NFLX_CLOSE          0.022382         0.036491            0.613           0.540
# L4.NFLX_VOLUME         0.000000         0.000000            1.270           0.204
# L5.NFLX_CLOSE          0.092904         0.036540            2.543           0.011
# L5.NFLX_VOLUME        -0.000000         0.000000           -0.929           0.353
# =================================================================================
#
# Results for equation NFLX_VOLUME
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const              71525.706375    119909.257128            0.596           0.551
# L1.NFLX_CLOSE     -27001.053001      9155.797608           -2.949           0.003
# L1.NFLX_VOLUME        -0.299225         0.036282           -8.247           0.000
# L2.NFLX_CLOSE       -126.814098      9194.997195           -0.014           0.989
# L2.NFLX_VOLUME        -0.198299         0.037555           -5.280           0.000
# L3.NFLX_CLOSE      -8559.375440      9187.023088           -0.932           0.352
# L3.NFLX_VOLUME        -0.229862         0.037355           -6.153           0.000
# L4.NFLX_CLOSE     -13133.704566      9179.239477           -1.431           0.152
# L4.NFLX_VOLUME        -0.148208         0.037595           -3.942           0.000
# L5.NFLX_CLOSE     -18041.218172      9191.511133           -1.963           0.050
# L5.NFLX_VOLUME        -0.055482         0.035736           -1.553           0.121
# =================================================================================
#
# Correlation matrix of residuals
#                NFLX_CLOSE  NFLX_VOLUME
# NFLX_CLOSE       1.000000     0.155456
# NFLX_VOLUME      0.155456     1.000000
#
#
#
#
# Ljung-Box Test for Residuals (one per variable):
# NFLX_CLOSE: p-value = 1.0000 No autocorrelation
# NFLX_VOLUME: p-value = 0.1642 No autocorrelation

# %%
forecasted_closes['NFLX'] = forecast_restored

# %% [markdown]
# **TSLA**

# %%
# 1. Define the stock
stock = 'TSLA'

# 2. Prepare the data
ts_stock = df[[f'{stock}_CLOSE', f'{stock}_VOLUME']].dropna()

# 3. Use only last 3 years (or change to 5 if needed)
end_date = ts_stock.index.max()
start_cutoff = end_date - pd.DateOffset(years=3)
ts_stock = ts_stock.loc[ts_stock.index >= start_cutoff]

# 4. Set business day frequency and forward fill missing
ts_stock = ts_stock.asfreq('B').fillna(method='ffill')

# 5. Difference the series to make it stationary
ts_stock_diff = ts_stock.diff().dropna()

# 6. Fit the VAR model
model = VAR(ts_stock_diff)
lag_order = model.select_order(15).aic
fitted_model = model.fit(lag_order)

# 7. Forecast next 60 business days
forecast_steps = 60
forecast_input = ts_stock_diff.values[-lag_order:]
forecast = fitted_model.forecast(y=forecast_input, steps=forecast_steps)
forecast_df = pd.DataFrame(forecast, columns=ts_stock_diff.columns)

# 8. Invert differencing
last_known = ts_stock.iloc[-1]
forecast_cumsum = forecast_df.cumsum()
forecast_restored = forecast_cumsum.add(last_known)

# 9. Assign dates to forecast
forecast_dates = pd.date_range(start=ts_stock.index[-1] + pd.Timedelta(days=1), periods=forecast_steps, freq='B')
forecast_restored.index = forecast_dates

# 10. Plot the forecast
plt.figure(figsize=(12, 6))
plt.plot(ts_stock[f'{stock}_CLOSE'][-60:], label='Historical')
plt.plot(forecast_restored[f'{stock}_CLOSE'], label='Forecast', linestyle='--')
plt.title(f"{stock} Forecasted Close Price (Next {forecast_steps} Business Days)")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# 11. Print summary
print(f"\nVAR Model Summary for {stock} (Lag={lag_order}):")
print(fitted_model.summary())

# 12. Ljung-Box Test for autocorrelation
from statsmodels.stats.diagnostic import acorr_ljungbox

print("\nLjung-Box Test for Residuals (one per variable):")
for col in fitted_model.resid.columns:
    lb_test = acorr_ljungbox(fitted_model.resid[col], lags=[lag_order], return_df=True)
    p_value = lb_test['lb_pvalue'].values[0]
    print(f"{col}: p-value = {p_value:.4f} {'No autocorrelation' if p_value > 0.05 else 'Possibly autocorrelated'}")
# Out:
# C:\Users\shamg\AppData\Local\Temp\ipykernel_13408\1844249523.py:13: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ts_stock = ts_stock.asfreq('B').fillna(method='ffill')
# VAR Model Summary for TSLA (Lag=9):
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 09, Jul, 2025
# Time:                     09:06:04
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    38.8562
# Nobs:                     773.000    HQIC:                   38.7156
# Log likelihood:          -17085.2    FPE:                5.96703e+16
# AIC:                      38.6276    Det(Omega_mle):     5.68417e+16
# --------------------------------------------------------------------
# Results for equation TSLA_CLOSE
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.012356         0.340817            0.036           0.971
# L1.TSLA_CLOSE          0.004883         0.036087            0.135           0.892
# L1.TSLA_VOLUME         0.000000         0.000000            1.788           0.074
# L2.TSLA_CLOSE          0.021448         0.036002            0.596           0.551
# L2.TSLA_VOLUME         0.000000         0.000000            1.209           0.227
# L3.TSLA_CLOSE         -0.047032         0.035972           -1.307           0.191
# L3.TSLA_VOLUME         0.000000         0.000000            2.424           0.015
# L4.TSLA_CLOSE          0.002818         0.036007            0.078           0.938
# L4.TSLA_VOLUME         0.000000         0.000000            0.467           0.641
# L5.TSLA_CLOSE          0.020395         0.036092            0.565           0.572
# L5.TSLA_VOLUME         0.000000         0.000000            0.623           0.533
# L6.TSLA_CLOSE          0.025694         0.036184            0.710           0.478
# L6.TSLA_VOLUME        -0.000000         0.000000           -0.191           0.849
# L7.TSLA_CLOSE          0.037566         0.036047            1.042           0.297
# L7.TSLA_VOLUME        -0.000000         0.000000           -0.119           0.905
# L8.TSLA_CLOSE          0.020747         0.036064            0.575           0.565
# L8.TSLA_VOLUME        -0.000000         0.000000           -2.702           0.007
# L9.TSLA_CLOSE          0.103667         0.036001            2.880           0.004
# L9.TSLA_VOLUME        -0.000000         0.000000           -0.054           0.957
# =================================================================================
#
# Results for equation TSLA_VOLUME
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const              -6664.875621    906015.352804           -0.007           0.994
# L1.TSLA_CLOSE      74137.098076     95931.371149            0.773           0.440
# L1.TSLA_VOLUME        -0.439307         0.036276          -12.110           0.000
# L2.TSLA_CLOSE     -60008.268399     95707.579411           -0.627           0.531
# L2.TSLA_VOLUME        -0.331954         0.039436           -8.418           0.000
# L3.TSLA_CLOSE      61705.226067     95625.629294            0.645           0.519
# L3.TSLA_VOLUME        -0.252156         0.041015           -6.148           0.000
# L4.TSLA_CLOSE    -144296.274115     95720.504654           -1.507           0.132
# L4.TSLA_VOLUME        -0.237258         0.041466           -5.722           0.000
# L5.TSLA_CLOSE     107874.191034     95944.681530            1.124           0.261
# L5.TSLA_VOLUME        -0.191161         0.041838           -4.569           0.000
# L6.TSLA_CLOSE     -41356.759323     96189.650119           -0.430           0.667
# L6.TSLA_VOLUME        -0.228543         0.041468           -5.511           0.000
# L7.TSLA_CLOSE      47282.522261     95827.195474            0.493           0.622
# L7.TSLA_VOLUME        -0.142203         0.041304           -3.443           0.001
# L8.TSLA_CLOSE    -102233.580855     95871.986314           -1.066           0.286
# L8.TSLA_VOLUME        -0.145758         0.039814           -3.661           0.000
# L9.TSLA_CLOSE     -33392.642588     95704.253924           -0.349           0.727
# L9.TSLA_VOLUME        -0.052783         0.036937           -1.429           0.153
# =================================================================================
#
# Correlation matrix of residuals
#                TSLA_CLOSE  TSLA_VOLUME
# TSLA_CLOSE       1.000000     0.021499
# TSLA_VOLUME      0.021499     1.000000
#
#
#
#
# Ljung-Box Test for Residuals (one per variable):
# TSLA_CLOSE: p-value = 1.0000 No autocorrelation
# TSLA_VOLUME: p-value = 0.9960 No autocorrelation

# %%
forecasted_closes['TSLA'] = forecast_restored

# %% [markdown]
# **Saving the forecasted dataset**

# %%
# 1. Define top 5 stocks
top_5_stocks = ['NVDA', 'AMD', 'AVGO', 'NFLX', 'TSLA']

# 2. Extract actuals
actuals = df[[f"{stock}_CLOSE" for stock in top_5_stocks]].copy()
actuals.reset_index(inplace=True)  # 'Date' was index
actuals['Type'] = 'Actual'

# 3. Collect forecasted values into one DataFrame
forecast_frames = []

for stock in top_5_stocks:
    try:
        forecast_df = forecasted_closes[stock].copy()  # must exist from your earlier steps
    except KeyError:
        print(f"⚠️ No forecast found for {stock}, skipping.")
        continue

    # Rename to match actuals (e.g., NVDA → NVDA_CLOSE)
    forecast_df = forecast_df[[f'{stock}_CLOSE']].copy()
    forecast_df.columns = [f'{stock}_CLOSE']
    forecast_df.reset_index(inplace=True)
    forecast_df.rename(columns={'index': 'Date'}, inplace=True)
    forecast_df['Type'] = 'Forecasted'
    forecast_frames.append(forecast_df)

# 4. Merge all forecast DataFrames on 'Date'
from functools import reduce

if forecast_frames:
    forecast_merged = reduce(lambda left, right: pd.merge(left, right, on=['Date', 'Type'], how='outer'), forecast_frames)
else:
    forecast_merged = pd.DataFrame()

# 5. Combine with actuals
final_df = pd.concat([actuals, forecast_merged], ignore_index=True, sort=False)
final_df.sort_values(by='Date', inplace=True)
final_df.reset_index(drop=True, inplace=True)

# %%
final_df.head()
# Out:
#         Date  NVDA_CLOSE  AMD_CLOSE  AVGO_CLOSE  NFLX_CLOSE  TSLA_CLOSE  \
# 0 2015-01-01         NaN        NaN         NaN         NaN         NaN
# 1 2015-01-02     0.50325       2.67      10.009   49.848572   14.620667
# 2 2015-01-05     0.49475       2.66       9.849   47.311428   14.006000
# 3 2015-01-06     0.47975       2.63       9.625   46.501431   14.085333
# 4 2015-01-07     0.47850       2.58       9.885   46.742859   14.063333
#
#      Type
# 0  Actual
# 1  Actual
# 2  Actual
# 3  Actual
# 4  Actual

# %%
final_df.tail()
# Out:
#            Date  NVDA_CLOSE   AMD_CLOSE  AVGO_CLOSE   NFLX_CLOSE  TSLA_CLOSE  \
# 2800 2025-09-24  170.235118  141.615031  289.345438  1352.208193  292.915901
# 2801 2025-09-25  170.420797  141.687603  289.632699  1353.602425  292.930967
# 2802 2025-09-26  170.606477  141.760176  289.919971  1354.996656  292.946026
# 2803 2025-09-29  170.792156  141.832748  290.207231  1356.390888  292.961088
# 2804 2025-09-30  170.977836  141.905321  290.494478  1357.785119  292.976156
#
#             Type
# 2800  Forecasted
# 2801  Forecasted
# 2802  Forecasted
# 2803  Forecasted
# 2804  Forecasted

# %%
# 6. Save to CSV
final_df.to_csv(r"D:\Masters Study Abroad\BA 2nd Sem\IS6611 Applied Research in Business Analytics\IS6611 IT Artefact V3\Final Files\Final Datasets\NASDAQ Datasets\NASDAQ_100_top_performers.csv", index=False)

# %% [markdown]
# # Calculating the Portfolio Growth
# **Simulating investments, invested equally in the top 5 stocks (NVDA, AMD, AVGO, NFLX, TSLA) back in 2015**

# %%
import pandas as pd

# Use actuals only (up to the last real date before forecast)
top_5_stocks = ['NVDA', 'AMD', 'AVGO', 'NFLX', 'TSLA']
close_cols = [f'{stock}_CLOSE' for stock in top_5_stocks]

# Extract close price data
actuals_df = df[close_cols].copy()
actuals_df = actuals_df.dropna(how='any')  # only use dates with all 5 present
actuals_df.reset_index(inplace=True)
actuals_df.rename(columns={'index': 'Date'}, inplace=True)

# Step 1: Normalize all stocks to start at 1.0
normalized_df = actuals_df.copy()
for col in close_cols:
    normalized_df[col] = normalized_df[col] / normalized_df[col].iloc[0]

# Step 2: Calculate equal-weighted portfolio value
normalized_df['Portfolio_Growth (%)'] = normalized_df[close_cols].mean(axis=1)

# Step 4: Keep only necessary columns
ideal_portfolio_growth_df = normalized_df[['Date', 'Portfolio_Growth (%)']]

# %%
ideal_portfolio_growth_df.head()
# Out:
#         Date  Portfolio_Growth (%)
# 0 2015-01-02              1.000000
# 1 2015-01-05              0.974088
# 2 2015-01-06              0.959239
# 3 2015-01-07              0.960860
# 4 2015-01-08              0.983992

# %%
ideal_portfolio_growth_df.tail()
# Out:
#            Date  Portfolio_Growth (%)
# 2638 2025-07-01             85.713150
# 2639 2025-07-02             87.735879
# 2640 2025-07-03             88.671617
# 2641 2025-07-07             87.658316
# 2642 2025-07-08             88.531953

# %%
#Save to CSV
ideal_portfolio_growth_df.to_csv(r"D:\Masters Study Abroad\BA 2nd Sem\IS6611 Applied Research in Business Analytics\IS6611 IT Artefact V3\Final Files\Final Datasets\NASDAQ Datasets\Top_performers_Portfolio_Growth.csv", index=False)
